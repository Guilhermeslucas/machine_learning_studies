# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

train_input = pd.read_csv('train.csv')
train_target = train_input["SalePrice"]
train_input = train_input.drop("SalePrice", axis=1)

# %% [markdown]
# ### Lets take a look of whats the training data looks like

# %%
# import pandas_profiling
# profile_report = pandas_profiling.ProfileReport(train_input)
# profile_report

# %%
def HandleMissingValues(df):
    # for Object columns fill using 'UNKOWN'
    # for Numeric columns fill using median
    num_cols = [cname for cname in df.columns if df[cname].dtype in ['int64', 'float64']]
    values = {}

    for a in num_cols:
        values[a] = df[a].median()
        
    df.fillna(value=values,inplace=True)
    
    
HandleMissingValues(train_input)
train_input.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ### One hot encoding

# %%
string_cols = [cname for cname in train_input.columns if train_input[cname].dtype == "object"]
string_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
from sklearn.preprocessing import LabelEncoder

for column in string_cols:
  encoder = LabelEncoder()
  train_input[column]= encoder.fit_transform(train_input[column].values)

train_input.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      2         3
# 1   2          20         3         80.0     9600       1      2         3
# 2   3          60         3         68.0    11250       1      2         0
# 3   4          70         3         60.0     9550       1      2         0
# 4   5          60         3         84.0    14260       1      2         0
#
#    LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0            3          0  ...            0         0       3      4
# 1            3          0  ...            0         0       3      4
# 2            3          0  ...            0         0       3      4
# 3            3          0  ...            0         0       3      4
# 4            3          0  ...            0         0       3      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ### Scaling the features

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_input = scaler.fit_transform(train_input)

train_input
# Out:
# array([[-1.73086488,  0.07337496, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        [-1.7284922 , -0.87256276, -0.04553194, ..., -0.61443862,
#          0.31386709,  0.2085023 ],
#        [-1.72611953,  0.07337496, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        ...,
#        [ 1.72611953,  0.30985939, -0.04553194, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [ 1.7284922 , -0.87256276, -0.04553194, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [ 1.73086488, -0.87256276, -0.04553194, ...,  0.13877749,
#          0.31386709,  0.2085023 ]])

# %% [markdown]
# ### Reducing dimensionality

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 20)
train_input = pca.fit_transform(train_input)

train_input
# Out:
# array([[ 2.18333563, -0.02430663, -2.1117648 , ...,  0.30410538,
#         -0.80124561,  0.40112884],
#        [ 0.19484957, -1.7361398 ,  1.54065554, ...,  0.02297384,
#          2.60078932, -0.70060777],
#        [ 2.71848077, -0.13167122, -1.56899462, ..., -0.02774022,
#         -0.0842402 , -0.65569082],
#        ...,
#        [ 1.11045566,  2.80016238,  1.03558347, ...,  1.13260617,
#         -0.4535702 ,  1.10358513],
#        [-2.97772396, -2.57216431,  2.14320385, ..., -1.16982275,
#         -0.32369965,  0.30487569],
#        [-0.87481102, -2.45110407,  1.8743449 , ..., -1.21708278,
#         -1.04625401,  0.85060765]])

# %% [markdown]
# ### Defining model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 200, random_state = 0)
regressor.fit(train_input, train_target)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=0)

# %% [markdown]
# ### Score

# %%
regressor.score(train_input, train_target)
# Out:
# 0.9777065109860674

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import pandas as pd

input_data = pd.read_csv('mushrooms.csv')

# %% [markdown]
# Now split into train an test

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(input_data, test_size=0.2)

# %% [markdown]
# Train shape

# %%
train_df.shape
# Out:
# (6499, 23)

# %% [markdown]
# Test shape

# %%
test_df.shape
# Out:
# (1625, 23)

# %% [markdown]
# Selecting and dropping target column for train dataset

# %%
train_target = train_df['class']
train_features = train_df.drop('class', axis=1)
train_features
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6871         x           s         e       f    y               f
# 4341         f           y         e       t    n               f
# 1779         x           s         n       f    n               f
# 6036         x           y         e       f    f               f
# 7274         k           s         n       f    f               f
# ...        ...         ...       ...     ...  ...             ...
# 4781         f           f         g       f    f               f
# 4255         x           y         g       f    f               f
# 5913         k           y         n       t    n               f
# 7318         k           s         e       f    s               f
# 6953         k           s         n       f    s               f
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 6871            c         n          b           t  ...
# 4341            c         b          w           t  ...
# ...

# %% [markdown]
# Selecting and dropping target column for test dataset

# %%
test_target = test_df['class']
test_features = test_df.drop('class', axis=1)
test_features
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1933         f           f         g       f    n               f
# 4927         f           f         y       f    f               f
# 7907         b           f         w       f    n               f
# 5983         f           y         y       f    f               f
# 2021         x           y         g       t    n               f
# ...        ...         ...       ...     ...  ...             ...
# 6217         k           s         e       f    f               f
# 5289         f           s         g       t    f               f
# 883          x           y         w       t    l               f
# 3647         x           f         g       f    f               f
# 981          x           s         y       t    l               f
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 1933            w         b          k           t  ...
# 4927            c         b          h           e  ...
# ...

# %% [markdown]
# One hot encoding

# %%
test_features = pd.get_dummies(test_features)
train_features = pd.get_dummies(train_features)

# %% [markdown]
# Binary class encoding

# %%
from sklearn.preprocessing import LabelEncoder

test_target = LabelEncoder().fit_transform(test_target)
train_target = LabelEncoder().fit_transform(train_target)

# %% [markdown]
# Try models

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_estimators=200, random_state=42)
rf_classifier.fit(train_features, train_target)

rf_prediction = rf_classifier.predict(test_features)

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(train_features, train_target)
dt_prediction = dt_classifier.predict(test_features)

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBClassifier

xgb_classifier = XGBClassifier()
xgb_classifier.fit(train_features, train_target)
xgb_prediction = xgb_classifier.predict(test_features)

# %% [markdown]
# Check accuracy score

# %%
from sklearn.metrics import accuracy_score

rf_accuracy = accuracy_score(rf_prediction, test_target)
print("Random Forest Classifier Accuracy:", rf_accuracy)

dt_accuracy = accuracy_score(dt_prediction, test_target)
print("Decision Tree Classifier Accuracy:", dt_accuracy)

xgb_accuracy = accuracy_score(xgb_prediction, test_target)
print("XGBoost Classifier Accuracy:", xgb_accuracy)
# Out:
# Random Forest Classifier Accuracy: 1.0
# Decision Tree Classifier Accuracy: 1.0
# XGBoost Classifier Accuracy: 1.0

# %% [markdown]
# Model Explainability

# %%
importance_df = pd.DataFrame({'Feature': train_features.columns, 'Importance': rf_classifier.feature_importances_})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                        Feature  Importance
# 27                      odor_n    0.138924
# 24                      odor_f    0.075969
# 36                 gill-size_n    0.065628
# 35                 gill-size_b    0.056887
# 61  stalk-surface-below-ring_k    0.051616
# ..                         ...         ...
# 99         spore-print-color_o    0.000000
# 84                veil-color_o    0.000000
# 83                veil-color_n    0.000000
# 43                gill-color_o    0.000000
# 82                 veil-type_p    0.000000
#
# [117 rows x 2 columns]

# %%
importance_df = pd.DataFrame({'Feature': train_features.columns, 'Importance': dt_classifier.feature_importances_})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                         Feature  Importance
# 27                       odor_n    0.619921
# 53                 stalk-root_c    0.176917
# 63   stalk-surface-below-ring_y    0.098480
# 100         spore-print-color_r    0.034182
# 34               gill-spacing_w    0.023733
# ..                          ...         ...
# 38                 gill-color_e    0.000000
# 37                 gill-color_b    0.000000
# 35                  gill-size_b    0.000000
# 33               gill-spacing_c    0.000000
# 116                   habitat_w    0.000000
#
# [117 rows x 2 columns]

# %%
importance_df = pd.DataFrame({'Feature': train_features.columns, 'Importance': xgb_classifier.feature_importances_})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                         Feature  Importance
# 53                 stalk-root_c    0.331832
# 27                       odor_n    0.297448
# 55                 stalk-root_r    0.182901
# 100         spore-print-color_r    0.048769
# 63   stalk-surface-below-ring_y    0.030630
# ..                          ...         ...
# 11                  cap-color_c    0.000000
# 12                  cap-color_e    0.000000
# 50                stalk-shape_t    0.000000
# 13                  cap-color_g    0.000000
# 116                   habitat_w    0.000000
#
# [117 rows x 2 columns]
